# %%
import pandas
import matplotlib.pyplot as plt
import seaborn


#ISO-8859-1
sdata = pandas.read_csv('/Users/kevinruiz/Documents/GitHub/HTH-2023-Spotify-Data-Analysis/Data/Spotify-2023.csv',encoding='latin-1')

sdata = sdata.drop([0, 574])

sdata['streams'] = pandas.to_numeric(sdata['streams'],errors='coerce')

sdata
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 1                         LALA         Myke Towers             1
# 2                      vampire      Olivia Rodrigo             1
# 3                 Cruel Summer        Taylor Swift             1
# 4               WHERE SHE GOES           Bad Bunny             1
# 5                     Sprinter   Dave, Central Cee             2
# ..                         ...                 ...           ...
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# 5             2023               6             1                  2186
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# 5                   91  183706234                  67  ...  141  C#  Major
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# 5               92         66       58             19                   0
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# 5             8             24
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [951 rows x 24 columns]

# %%
### 1. What were the top 5 most popular songs from the 90's? And plot their streams in a bar graph.


nineties_tracks = sdata[(sdata['released_year'] >= 1990)&(sdata['released_year']<=1999)]
sorted = nineties_tracks.sort_values('streams',ascending = False).iloc[1:6]
sorted

seaborn.barplot(x= sorted['track_name'], y=sorted['streams'], width = 0.6, dodge=False)
# Out:
# <Axes: xlabel='track_name', ylabel='streams'>

# %%
### 2. How much streams did Ed Sheran's top 3 songs earn in total? Create a pie chart comparing all three of them. 

ed_sheran = sdata[(sdata['artist(s)_name'] == 'Ed Sheeran')].sort_values('streams',ascending = False).iloc[1:4]

ed_sheran

plt.pie(ed_sheran['streams'], labels =ed_sheran['track_name'], autopct='%1.1f%%')

#autopct='%1.1f%%'
# Out:
# ([<matplotlib.patches.Wedge at 0x11bd95b50>,
#   <matplotlib.patches.Wedge at 0x11bd95ac0>,
#   <matplotlib.patches.Wedge at 0x11bd7e090>],
#  [Text(0.4630951686481498, 0.9977689435809985, 'Perfect'),
#   Text(-1.088720702349625, -0.1571217116611816, 'Thinking Out Loud'),
#   Text(0.6008660466455249, -0.921390250647671, 'Photograph')],
#  [Text(0.2525973647171726, 0.5442376055896355, '36.2%'),
#   Text(-0.5938476558270681, -0.08570275181518995, '32.2%'),
#   Text(0.32774511635210446, -0.5025765003532751, '31.6%')])
